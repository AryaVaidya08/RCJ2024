# %%
import pandas as pd

# %%
red_data = pd.read_csv("./full-red-data.csv")

# %%
red_data
# Out:
#      Unnamed: 0  Blue  Green  Red  Blue : Green  Green : Red  Blue : Red  \
# 0             0   122    106  250      1.150943     0.424000    0.488000
# 1             1   129    110  254      1.172727     0.433071    0.507874
# 2             2   130    111  246      1.171171     0.451220    0.528455
# 3             3   122    105  240      1.161905     0.437500    0.508333
# 4             4   125    107  244      1.168224     0.438525    0.512295
# ..          ...   ...    ...  ...           ...          ...         ...
# 200         200   100     91  230      1.098901     0.395652    0.434783
# 201         201   103     92  229      1.119565     0.401747    0.449782
# 202         202    97     89  227      1.089888     0.392070    0.427313
# 203         203   104     94  230      1.106383     0.408696    0.452174
# 204         204   101     90  229      1.122222     0.393013    0.441048
#
#      Blue * Green : Red  Green * Red : Blue  Blue * Red : Green  Red : Blue  \
# ...

# %%
red_data["Red : Blue"] = red_data["Red"] / red_data["Blue"]
red_data["Red : Green"] = red_data["Red"] / red_data["Green"]
red_data["Green : Blue"] = red_data["Green"] / red_data["Blue"]

# %%
red_data.describe()
# Out:
#        Unnamed: 0        Blue       Green         Red  Blue : Green  \
# count  205.000000  205.000000  205.000000  205.000000    205.000000
# mean   102.000000  105.234146   90.604878  230.268293      1.163217
# std     59.322565   11.737480   10.597122    6.074797      0.045485
# min      0.000000   71.000000   60.000000  217.000000      1.055556
# 25%     51.000000   97.000000   84.000000  226.000000      1.132075
# 50%    102.000000  105.000000   90.000000  230.000000      1.164706
# 75%    153.000000  113.000000   97.000000  234.000000      1.191011
# max    204.000000  135.000000  121.000000  254.000000      1.301370
#
#        Green : Red  Blue : Red  Blue * Green : Red  Green * Red : Blue  \
# count   205.000000  205.000000          205.000000          205.000000
# mean      0.392926    0.456479            0.556210            1.130277
# std       0.039662    0.044235            0.310315            0.707313
# ...
