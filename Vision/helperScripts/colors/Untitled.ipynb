# %%
import pandas as pd

# %%
yellow_data = pd.read_csv("./full-yellow-data.csv")

# %%
yellow_data
# Out:
#     Unnamed: 0  Blue  Green  Red  Blue : Green  Green : Red  Blue : Red  \
# 0            0   102    208  214      0.490385     0.971963    0.476636
# 1            1    95    196  200      0.484694     0.980000    0.475000
# 2            2    98    198  200      0.494949     0.990000    0.490000
# 3            3    87    188  192      0.462766     0.979167    0.453125
# 4            4    95    199  201      0.477387     0.990050    0.472637
# 5            5   100    206  210      0.485437     0.980952    0.476190
# 6            6    97    198  204      0.489899     0.970588    0.475490
# 7            7    92    198  200      0.464646     0.990000    0.460000
# 8            8    92    198  201      0.464646     0.985075    0.457711
# 9            9    95    198  204      0.479798     0.970588    0.465686
# 10          10    96    200  204      0.480000     0.980392    0.470588
# 11          11    99    202  206      0.490099     0.980583    0.480583
# ...

# %%
yellow_data["G * R / B"] = (yellow_data["Green"] * yellow_data["Red"]) / yellow_data["Blue"]
