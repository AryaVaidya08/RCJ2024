# %%
import pandas as pd

# %%
green_data = pd.read_csv("./full-green-data.csv")

# %%
green_data
# Out:
#      Unnamed: 0  Blue  Green  Red  Blue : Green  Green : Red  Blue : Red  \
# 0             0   144    202  121      0.712871     1.669421    1.190083
# 1             1   134    191  111      0.701571     1.720721    1.207207
# 2             2   146    205  127      0.712195     1.614173    1.149606
# 3             3   139    195  117      0.712821     1.666667    1.188034
# 4             4   140    195  113      0.717949     1.725664    1.238938
# ..          ...   ...    ...  ...           ...          ...         ...
# 211         211   147    200  122      0.735000     1.639344    1.204918
# 212         212   150    205  125      0.731707     1.640000    1.200000
# 213         213   146    199  119      0.733668     1.672269    1.226891
# 214         214   139    192  110      0.723958     1.745455    1.263636
# 215         215   153    206  126      0.742718     1.634921    1.214286
#
#      Blue * Green : Red  Green * Red : Blue  Blue * Red : Green  Green : Blue
# ...

# %%
#green_data["Green : Blue"] = green_data["Green"] / green_data["Blue"]
green_data["Green : Red"] = green_data["Green"] / green_data["Red"]

# %%
green_data.describe()
# Out:
#        Unnamed: 0        Blue       Green         Red  Blue : Green  \
# count     216.000  216.000000  216.000000  216.000000    216.000000
# mean      107.500  135.879630  195.777778  115.703704      0.693687
# std        62.498    7.790534    6.996788    7.251956      0.021944
# min         0.000  110.000000  173.000000   97.000000      0.635359
# 25%        53.750  131.000000  191.000000  111.000000      0.678609
# 50%       107.500  137.000000  196.000000  116.000000      0.696517
# 75%       161.250  141.000000  201.000000  121.000000      0.708802
# max       215.000  153.000000  215.000000  139.000000      0.742718
#
#        Green : Red  Blue : Red  Blue * Green : Red  Green * Red : Blue  \
# count   216.000000  216.000000          216.000000          216.000000
# mean      1.695253    1.175579            1.012437            0.855582
# std       0.056991    0.044721            0.654806            0.553656
# ...
